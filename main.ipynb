# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
idPlanilha = 0
listaPlanilha = []
while True:
    try:
        listaPlanilha.append(pd.read_excel("INC02-POR-2024-08.xlsx",sheet_name=idPlanilha, header=3))
        idPlanilha+=1
    except Exception:
        break

# %%
plt.plot(listaPlanilha[1]["desloc_A"],listaPlanilha[1]["Depth"])
